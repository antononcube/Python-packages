# %% [markdown]
# # Random mandalas

# %%
from RandomMandala import *
from JavaScriptD3 import *
import random

# %%
# %%javascript
# require.config({
#      paths: {
#      d3: 'https://d3js.org/d3.v7.min'
# }});
#
# require(['d3'], function(d3) {
#      console.log(d3);
# });

# %%
# random_mandala(n_rows=2, n_columns=4).show

# %%
js_d3_random_mandala()

# %%
js_d3_random_mandala(count=8,
                     radius=1,
                     rotational_symmetry_order=None,
                     symmetric_seed=random.choice([True,False]),
                     number_of_seed_elements=None,
                     connecting_function=random.choice(["Bundle", "Basis"]),
                     background='',
                     color='',
                     fill="silver",
                     margins=10,
                     fmt="jupyter")
